# %%
import stackhunter as sh
nb = sh.notebook()

# %%
#!pip install GitPython
from git import Repo
Repo.clone_from('https://github.com/jt0dd/manifestjs', 'tmp')
# Out:
# <git.repo.base.Repo '/mnt/c/Users/jonat/Documents/GitHub/stack-hunter/notebooks/001/tmp/.git'>
